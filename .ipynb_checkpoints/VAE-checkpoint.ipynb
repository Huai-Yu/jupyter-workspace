# %% [markdown]
# # 載入套件

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import interact, IntSlider, FloatSlider

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Lambda, concatenate
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras import metrics
from tensorflow.keras import losses
from tensorflow.keras import datasets
from tensorflow.keras.utils import to_categorical

import os

os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %% [markdown]
# # 載入MNIST資料集

# %%
(X_train, y_train0), (X_test, y_test0) = datasets.mnist.load_data()
X_train = X_train.reshape(-1, 28*28)
X_test = X_test.reshape(-1, 28*28)
X_train = X_train / X_train.max()
X_test = X_test / X_test.max()
y_train = to_categorical(y_train0, 10)
y_test = to_categorical(y_test0, 10)
x = Input(shape=(784,))

# %% [markdown]
# # 建立VAE

# %%
enc_1 = Dense(100, activation='sigmoid') 
enc_2 = Dense(235, activation='relu') ##調整參數
enc_3 = Dense(235, activation='sigmoid') ##增加第三層encoding層

enc_mean = Dense(2)
enc_log_var = Dense(2)

dec_3 = Dense(150, activation='sigmoid') ##調整參數
dec_2 = Dense(350, activation='sigmoid') ##調整參數
dec_1 = Dense(784, activation='sigmoid') ##增加第三層decoding層

# %%
x = Input(shape=(784,))
enc_x = enc_3(enc_2(enc_1(x)))

z_mean = enc_mean(enc_x)
z_log_var = enc_log_var(enc_x)

# %%
def sampling(args):
    z_mean, z_log_var = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    # by default, random_normal has mean = 0 and std = 1.0
    epsilon = K.random_normal(shape=(batch, dim))
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

# %%
# Sampling function wrapped as a Keras layer
z = Lambda(sampling, output_shape=(2,))([z_mean, z_log_var])

# %%
z_input = Input(shape=(2,))
x_hat = dec_1(dec_2(dec_3(z_input)))

# %%
x_hat = dec_1(dec_2(dec_3(z)))

VAE = Model(x, x_hat)
VAE.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           [(None, 784)]        0
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 100)          78500       input_11[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 235)          23735       dense_24[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 235)          55460       dense_25[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 2)            472         dense_26[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 2)            472         dense_26[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 2)            0           dense_27[0][0]
#                                                                  dense_28[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 150)          450         lambda_3[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 350)          52850       dense_29[1][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 784)          275184      dense_30[1][0]
# ==================================================================================================
# Total params: 487,123
# Trainable params: 487,123
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # 建立loss函數

# %%
# reconstruction_loss = tf.keras.losses.mse(inputs, outputs)
reconstruction_loss = 784 * losses.binary_crossentropy(x, x_hat)

kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.7 ##-0.7
vae_loss = K.mean(reconstruction_loss + kl_loss)

VAE.add_loss(vae_loss)

# %%
VAE.compile(optimizer=Adam())
# Out:
# WARNING:tensorflow:Output dense_31 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to dense_31.

# %%
VAE.fit(X_train, 
        batch_size=512, ##512
        epochs=10) ##訓練10次
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 7s 111us/sample - loss: 225.6611
# Epoch 2/10
# 60000/60000 [==============================] - 6s 94us/sample - loss: 206.3331
# Epoch 3/10
# 60000/60000 [==============================] - 5s 91us/sample - loss: 203.9881
# Epoch 4/10
# 60000/60000 [==============================] - 6s 93us/sample - loss: 196.3946
# Epoch 5/10
# 60000/60000 [==============================] - 6s 93us/sample - loss: 193.7653
# Epoch 6/10
# 60000/60000 [==============================] - 6s 92us/sample - loss: 191.7795
# Epoch 7/10
# 60000/60000 [==============================] - 6s 94us/sample - loss: 187.7638
# Epoch 8/10
# 60000/60000 [==============================] - 6s 93us/sample - loss: 181.7623
# Epoch 9/10
# 60000/60000 [==============================] - 6s 95us/sample - loss: 178.2466
# Epoch 10/10
# 60000/60000 [==============================] - 6s 96us/sample - loss: 175.6049

# %% [markdown]
# # VAE視覺化

# %%
VAE_Encoder = Model(x, z_mean)

VAE_Encoder.summary()
# Out:
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 784)]             0
# _________________________________________________________________
# dense_24 (Dense)             (None, 100)               78500
# _________________________________________________________________
# dense_25 (Dense)             (None, 235)               23735
# _________________________________________________________________
# dense_26 (Dense)             (None, 235)               55460
# _________________________________________________________________
# dense_27 (Dense)             (None, 2)                 472
# =================================================================
# Total params: 158,167
# Trainable params: 158,167
# Non-trainable params: 0
# _________________________________________________________________

# %%
VAE_Decoder = Model(z_input, dec_1(dec_2(dec_3(z_input))))

VAE_Decoder.summary()
# Out:
# Model: "model_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        [(None, 2)]               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 150)               450
# _________________________________________________________________
# dense_30 (Dense)             (None, 350)               52850
# _________________________________________________________________
# dense_31 (Dense)             (None, 784)               275184
# =================================================================
# Total params: 328,484
# Trainable params: 328,484
# Non-trainable params: 0
# _________________________________________________________________

# %%
idx = np.random.randint(X_train.shape[0])
print(f"第 {idx} 圖的 latent 表示為 {VAE_Encoder.predict(X_train[idx: idx+1]).squeeze()}")
# Out:
# 第 16712 圖的 latent 表示為 [-0.5494814 -2.5854535]

# %%
indices = np.random.randint(X_train.shape[0], size=3000)

# %%
VAE_latents = VAE_Encoder.predict(X_train[indices])

# %%
plt.figure(figsize=(10, 8))
plt.scatter(VAE_latents[:, 0], VAE_latents[:, 1], c=y_train0[indices], cmap='tab20')
plt.colorbar()
plt.show()

# %% [markdown]
# # 總結
# ## 新增了一層encording層，原先嘗試batch size設定1024訓練8次，呈現出來的圖像趨近一條斜直線，後來改成512,10，完成訓練成果
